# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ***
#
# ### Exercise 1
#
# Create box plots on a single set of axes for all five experiments in the morley data set.

# %%
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/morley.csv')
# Dropping the "Unnamed column"
df = df.drop(columns=['Unnamed: 0'])
# Checking if ther is any null value
df.isnull().values.sum()
# Out:
# 0

# %%
df
# Out:
#     Expt  Run  Speed
# 0      1    1    850
# 1      1    2    740
# 2      1    3    900
# 3      1    4   1070
# 4      1    5    930
# ..   ...  ...    ...
# 95     5   16    940
# 96     5   17    950
# 97     5   18    800
# 98     5   19    810
# 99     5   20    870
#
# [100 rows x 3 columns]

# %%
# Separating the Experiemnts for the box plots
exp_1 = df.loc[df['Expt'] == 1]
exp_2 = df.loc[df['Expt'] == 2]
exp_3 = df.loc[df['Expt'] == 3]
exp_4 = df.loc[df['Expt'] == 4]
exp_5 = df.loc[df['Expt'] == 5]

# %%
fig, axs = plt.subplots(1,5,figsize=(15, 10))

# Experiment 1 Plot
axs[0].boxplot(exp_1['Speed'])
axs[0].set_title('Experiment 1', size=15)

# Ploting red dots for each value inside exp_1
axs[0].plot(np.ones(exp_1['Speed'].shape), exp_1['Speed'], 'r.')

# Plotting the mean value 
axs[0].plot([1.0], [np.mean(np.array(exp_1['Speed']))], 'go')



# Experiment 2 Plot
axs[1].boxplot(exp_2['Speed'])
axs[1].set_title('Experiment 2', size=15)

# Ploting red dots for each value inside exp_2
axs[1].plot(np.ones(exp_1['Speed'].shape), exp_2['Speed'], 'r.')

# Plotting the mean value 
axs[1].plot([1.0], [np.mean(np.array(exp_2['Speed']))], 'go')


# Experiment 3 Plot
axs[2].boxplot(exp_3['Speed'])
axs[2].set_title('Experiment 3', size=15)

# Ploting red dots for each value inside exp_3
axs[2].plot(np.ones(exp_3['Speed'].shape), exp_1['Speed'], 'r.')

# Plotting the mean value 
axs[2].plot([1.0], [np.mean(np.array(exp_3['Speed']))], 'go')


# Experiment 4 Plot
axs[3].boxplot(exp_4['Speed'])
axs[3].set_title('Experiment 4', size=15)

# Ploting red dots for each value inside exp_4
axs[3].plot(np.ones(exp_3['Speed'].shape), exp_4['Speed'], 'r.')

# Plotting the mean value 
axs[3].plot([1.0], [np.mean(np.array(exp_4['Speed']))], 'go')



# Experiment 5 Plot
axs[4].boxplot(exp_5['Speed'])
axs[4].set_title('Experiment 3', size=15)

# Ploting red dots for each value inside exp_5
axs[4].plot(np.ones(exp_3['Speed'].shape), exp_5['Speed'], 'r.')

# Plotting the mean value 
axs[4].plot([1.0], [np.mean(np.array(exp_5['Speed']))], 'go')

# %% [markdown]
# ***
#
# ### Exercise 2
#
#
# Create box plots for all of the numercial variables in Fisher's Iris Data Set.
#
# ***

# %%
# Reading the dataset
iris_df = pd.read_csv("https://gist.github.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
# Checking if ther is any null value
iris_df.isnull().values.sum()
# Out:
# 0

# %%
# looking at the df to see the name of the columns 
iris_df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# Breaking down the numerical variables per flower type
setosa = iris_df.loc[iris_df['variety'] == "Setosa"]
virginica = iris_df.loc[iris_df['variety'] == "Virginica"]
versicolor = iris_df.loc[iris_df['variety'] == "Versicolor"]

# %% [markdown]
# ## Sepal Length and width for each flower

# %%
# Plotting Sepal Length for each flower type

# Creating a figure with 2 lines and 3 columns
fig, axs = plt.subplots(2,3,figsize=(15, 10))



# Setosa Sepal Length Plot
axs[0,0].boxplot(setosa['sepal.length'])
axs[0,0].set_title('Setosa Sepal Length', size=15)

# Ploting red dots for each value inside the Sepal length colums for Setosas
axs[0,0].plot(np.ones(setosa['sepal.length'].shape), setosa['sepal.length'], 'r.')

# Plotting the mean value 
axs[0,0].plot([1.0], [np.mean(np.array(setosa['sepal.length']))], 'go')




# Virginica Sepal Length Plot
axs[0,1].boxplot(virginica['sepal.length'])
axs[0,1].set_title('Virginica Sepal Length', size=15)

# Ploting red dots for each value inside the Sepal length colums for Virginicas
axs[0,1].plot(np.ones(virginica['sepal.length'].shape), virginica['sepal.length'], 'r.')

# Plotting the mean value 
axs[0,1].plot([1.0], [np.mean(np.array(virginica['sepal.length']))], 'go')




# Versicolor Sepal Length Plot
axs[0,2].boxplot(versicolor['sepal.length'])
axs[0,2].set_title('Versicolor Sepal Length', size=15)

# Ploting red dots for each value inside the Sepal length colums for Versicolors
axs[0,2].plot(np.ones(versicolor['sepal.length'].shape), versicolor['sepal.length'], 'r.')

# Plotting the mean value 
axs[0,2].plot([1.0], [np.mean(np.array(versicolor['sepal.length']))], 'go')




# Plotting Sepal width for each flower type

# Setosa Sepal Width Plot
axs[1,0].boxplot(setosa['sepal.width'])
axs[1,0].set_title('Setosa Sepal Length', size=15)

# Ploting red dots for each value inside the Sepal Width colums for Setosas
axs[1,0].plot(np.ones(setosa['sepal.width'].shape), setosa['sepal.width'], 'r.')

# Plotting the mean value 
axs[1,0].plot([1.0], [np.mean(np.array(setosa['sepal.width']))], 'go')



# Virginica Sepal Width Plot
axs[1,1].boxplot(virginica['sepal.width'])
axs[1,1].set_title('Virginica Sepal Length', size=15)

# Ploting red dots for each value inside the Sepal Width colums for Virginicas
axs[1,1].plot(np.ones(virginica['sepal.width'].shape), virginica['sepal.width'], 'r.')

# Plotting the mean value 
axs[1,1].plot([1.0], [np.mean(np.array(virginica['sepal.width']))], 'go')



# Versicolor Sepal Width Plot
axs[1,2].boxplot(versicolor['sepal.width'])
axs[1,2].set_title('Versicolor Sepal Length', size=15)

# Ploting red dots for each value inside the Sepal Width colums for Versicolors
axs[1,2].plot(np.ones(versicolor['sepal.width'].shape), versicolor['sepal.width'], 'r.')

# Plotting the mean value 
axs[1,2].plot([1.0], [np.mean(np.array(versicolor['sepal.width']))], 'go')

# %%
# Plotting Petal Length for each flower type

# Creating a figure with 2 lines and 3 columns
fig, axs = plt.subplots(2,3,figsize=(15, 10))



# Setosa Petal Length Plot
axs[0,0].boxplot(setosa['petal.length'])
axs[0,0].set_title('Setosa Petal Length', size=15)

# Ploting red dots for each value inside the Petal length colums for Setosas
axs[0,0].plot(np.ones(setosa['petal.length'].shape), setosa['petal.length'], 'r.')

# Plotting the mean value 
axs[0,0].plot([1.0], [np.mean(np.array(setosa['petal.length']))], 'go')




# Virginica Petal Length Plot
axs[0,1].boxplot(virginica['petal.length'])
axs[0,1].set_title('Virginica Petal Length', size=15)

# Ploting red dots for each value inside the Petal length colums for Virginicas
axs[0,1].plot(np.ones(virginica['petal.length'].shape), virginica['petal.length'], 'r.')

# Plotting the mean value 
axs[0,1].plot([1.0], [np.mean(np.array(virginica['petal.length']))], 'go')




# Versicolor Petal Length Plot
axs[0,2].boxplot(versicolor['petal.length'])
axs[0,2].set_title('Versicolor Petal Length', size=15)

# Ploting red dots for each value inside the Petal length colums for Versicolors
axs[0,2].plot(np.ones(versicolor['petal.length'].shape), versicolor['petal.length'], 'r.')

# Plotting the mean value 
axs[0,2].plot([1.0], [np.mean(np.array(versicolor['petal.length']))], 'go')




# Plotting Petal width for each flower type

# Setosa Sepal Width Plot
axs[1,0].boxplot(setosa['petal.width'])
axs[1,0].set_title('Setosa Petal Length', size=15)

# Ploting red dots for each value inside the Petal Width colums for Setosas
axs[1,0].plot(np.ones(setosa['petal.width'].shape), setosa['petal.width'], 'r.')

# Plotting the mean value 
axs[1,0].plot([1.0], [np.mean(np.array(setosa['petal.width']))], 'go')



# Virginica Petal Width Plot
axs[1,1].boxplot(virginica['petal.width'])
axs[1,1].set_title('Virginica Petal Length', size=15)

# Ploting red dots for each value inside the Petal Width colums for Virginicas
axs[1,1].plot(np.ones(virginica['petal.width'].shape), virginica['petal.width'], 'r.')

# Plotting the mean value 
axs[1,1].plot([1.0], [np.mean(np.array(virginica['petal.width']))], 'go')



# Versicolor Sepal Width Plot
axs[1,2].boxplot(versicolor['petal.width'])
axs[1,2].set_title('Versicolor Petal Length', size=15)

# Ploting red dots for each value inside the Petal Width colums for Versicolors
axs[1,2].plot(np.ones(versicolor['petal.width'].shape), versicolor['petal.width'], 'r.')

# Plotting the mean value 
axs[1,2].plot([1.0], [np.mean(np.array(versicolor['petal.width']))], 'go')

# %% [markdown]
# ### Exercise 3
#
#
# Adapt the above code and plots so that the overall plot is inversely propertional and the individual groups are directly proportional.
#
# ***
