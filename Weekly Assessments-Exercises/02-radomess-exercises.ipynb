# %% [markdown]
# <h3 style="color: #001a79;">Exercise 1</h3>
#
# <hr style="border-top: 1px solid #001a79;" />
#
# <i h3 style="color: #001a79;">Remember to do these exercises in your own notebook in your assessment repository.</i>
#
# It is somewhat interesting that `(5 * 4 * 3 * 2 * 1)` perfectly divides `(10 * 9 * 8 * 7 * 6)` - there's no remainder.
#
# If we only wanted exactly four heads as opposed to five, the equivalent calculation would be `(10 * 9 * 8 * 7) / (4 * 3 * 2 * 1)`.
#
# Does that evenly divide too? What is the formula in general?
#
# Does it always come out as a positive whole number?
#
# <hr style="border-top: 1px solid #001a79;" />

# %% [markdown]
# The formula to find the number of possibilities to get 4 heads in 10 coin tosses is :
# <b>$\frac{10!}{4!(10-4)!}$</b> which after solving will become <b>$\frac{10!}{4!(6!)}$</b>. That is the same as <b>$\frac{10 * 9 * 8 * 7 * 6!}{4 * 3 * 2 * 1*(6!)}$</b>, dividig the 6! in the numerator and denominator will leave us with <b>$\frac{10 * 9 * 8 * 7}{4 * 3 * 2 * 1}$</b>, which reduces to <b>$\frac{5040}{24}$</b> which is equal to 210 possibilities.
#
#
#
#
# The formula used to find the number of probability to get 4 heads in 10 coin tosses is the following:
#
# <b>$\frac{n!}{(n-x)!x!}.(p)^x.q^{n-x}$</b> where, n is the number of experiments, x is the result that we want to achieve (in this case, getting 4 heads) p is probability of success in a single experiment, q is probability of failure.
#
# If we want to calculate the probability of getting 4 heads in 10 coin tosses:
#
# <b>$\frac{10!}{(10-4)!4!} * (0.5)^4 * (0.5)^{10-4}$</b>.

# %%
from math import factorial as fc
import matplotlib.pyplot as plt
x = 4
n = 10
p= 0.5
q= 0.5

prob = fc(n) / (fc(n-x)* fc(x)) * (p**x) * (q**(n-x))



print("The probability of getting 4 heads in 10 coin tosses is: ", prob*100, "%" )
# Out:
# The probability of getting 4 heads in 10 coin tosses is:  20.5078125 %

# %% [markdown]
# <b>References:</b>
#
# [Biominal Formula Reference](https://www.cuemath.com/binomial-distribution-formula/)
#
# [Mathematical Expressions Markdown](https://csrgxtu.github.io/2015/03/20/Writing-Mathematic-Fomulars-in-Markdown/#:~:text=Fractions%20and%20Binomials&text=%5Cfrac%7Bn!%7D%7B)

# %% [markdown]
# <h3 style="color: #001a79;">Exercise 2</h3>
#
# <hr style="border-top: 1px solid #001a79;" />
#
#
# Note that there are the same number of ways to get 4 tails as there to get 4 heads. Explain why this is.
#
# <hr style="border-top: 1px solid #001a79;" />

# %% [markdown]
# That happens because there is only two possible outcomes when tossing a coin, so when tossing a coin you have and you expect to get heads you have a 50% change to get the result and a 50% to not get a the desired result. So for every "heads" result there will always have a "fail heads" result, meaning that for every number of heads results there will always be a tails conterpart for it.
# That can be seem in the plot bellow were it shows that the possibility of getting 4 heads is the same as getting 4 tails.

# %%
import matplotlib.pyplot as plt
# The number of coins we will flip.
coins = 10

# The number from 0 to 10 inclusive.
x = list(range(coins + 1))

# The number of ways of selecting i things from 10. 
y = [math.comb(coins, i) for i in x]

# Display x and y as a bar chart.
plt.bar(x, y);

# %% [markdown]
# <h3 style="color: #001a79;">Exercise 3</h3>
#
# <hr style="border-top: 1px solid #001a79;" />
#
#
#
# Plot bar charts or histograms of any three different distributions listed at the following link:
#
# https://numpy.org/doc/stable/reference/random/generator.html#distributions
#
# <hr style="border-top: 1px solid #001a79;" />

# %% [markdown]
# <h3 style="color: #001a79;">Uniform Distribuition Chart</h3>

# %%
import numpy as np
import math

# %% [markdown]
# The Uniform distribution generate numbers picked from a set interval, with the equally likelly possibility of being generated. Because of that in the plot below we can see that the all 10 bins have almost the same amount of numbers in it.

# %%
#Uniform Distribution
#Creating a seed for testing 
#rng = np.random.default_rng(0)

#Generating Random data

rng = np.random.default_rng()
#Setting the variables. the function takes a low range, a hight(as optional) range and the size of the sample
low=10
hight = 150
size=100000

values = rng.uniform(low, hight, size)

plt.hist(values, edgecolor='blue') 
plt.title("Uniform Distribution") 
plt.show()

# %%
rng = np.random.default_rng()
#Setting the variables. the function takes a low range, a hight(as optional) range and the size of the sample
a= 2
b = 2
size=100000

values = rng.beta(a, b, size)

plt.hist(values, edgecolor='blue') 
plt.title("Beta Distribution") 
plt.show()

# %%
rng = np.random.default_rng()
#Setting the variables. the function takes a low range, a hight(as optional) range and the size of the sample

size = 200

values = rng.exponential(a,size)
plt.hist(values, edgecolor='blue') 
plt.title("Exponential Distribution") 
plt.show()
